# %% [markdown]
# # 데이터의 기본적인 설명

# %% [markdown]
# ## About Dataset
# This case requires to develop a customer segmentation to define marketing strategy. The
# sample Dataset summarizes the usage behavior of about 9000 active credit card holders during the last 6 months. The file is at a customer level with 18 behavioral variables.
#
# Following is the Data Dictionary for Credit Card dataset :-
#
# - `CUST_ID` : Identification of Credit Card holder (Categorical)
# - `BALANCE` : Balance amount left in their account to make purchases (
# - `BALANCE_FREQUENCY` : How frequently the Balance is updated, score between 0 and 1 (1 = frequently updated, 0 = not frequently updated)
# - `PURCHASES` : Amount of purchases made from account
# - `ONEOFF_PURCHASES` : Maximum purchase amount done in one-go
# - `INSTALLMENTS_PURCHASES` : Amount of purchase done in installment
# - `CASH_ADVANCE` : Cash in advance given by the user
# - `PURCHASES_FREQUENCY` : How frequently the Purchases are being made, score between 0 and 1 (1 = frequently purchased, 0 = not frequently purchased)
# - `ONEOFFPURCHASESFREQUENCY` : How frequently Purchases are happening in one-go (1 = frequently purchased, 0 = not frequently purchased)
# - `PURCHASESINSTALLMENTSFREQUENCY` : How frequently purchases in installments are being done (1 = frequently done, 0 = not frequently done)
# - `CASHADVANCEFREQUENCY` : How frequently the cash in advance being paid
# - `CASHADVANCETRX` : Number of Transactions made with "Cash in Advanced"
# - `PURCHASES_TRX` : Numbe of purchase transactions made
# - `CREDIT_LIMIT` : Limit of Credit Card for user
# - `PAYMENTS` : Amount of Payment done by user
# - `MINIMUM_PAYMENTS` : Minimum amount of payments made by user
# - `PRCFULLPAYMENT` : Percent of full payment paid by user
# - `TENURE` : Tenure of credit card service for user

# %% [markdown]
# 번역한 내용은 다음과 같다.
#
# ## 데이터셋 정보
# 이 사례는 마케팅 전략을 정의하기 위한 고객 세분화를 개발하는 것을 목표로 합니다. 제공된 샘플 데이터셋은 지난 6개월 동안 약 9000명의 활성 신용카드 소지자의 이용 행태를 요약한 것입니다. 이 파일은 고객 수준으로 구성되어 있으며, 18개의 행동 변수를 포함하고 있습니다.
#
# 다음은 신용카드 데이터셋에 대한 데이터 사전입니다.
#
# - `CUST_ID`: 신용카드 소지자 식별자 (범주형)
# - `BALANCE`: 계좌에 남아있는 구매 가능 잔액
# - `BALANCE_FREQUENCY`: 잔액 업데이트 빈도 (0과 1 사이의 값, 1은 매우 자주 업데이트됨, 0은 자주 업데이트되지 않음)
# - `PURCHASES`: 계좌에서 이루어진 총 구매 금액
# - `ONEOFF_PURCHASES`: 일시불 최대 구매 금액
# - `INSTALLMENTS_PURCHASES`: 할부 구매 총 금액
# - `CASH_ADVANCE`: 사용자가 인출한 현금 서비스 금액
# - `PURCHASES_FREQUENCY`: 구매가 이루어지는 빈도 (0과 1 사이의 값, 1은 매우 자주 구매, 0은 자주 구매하지 않음)
# - `ONEOFFPURCHASESFREQUENCY`: 일시불 구매가 이루어지는 빈도 (0과 1 사이의 값, 1은 매우 자주 구매, 0은 자주 구매하지 않음)
# - `PURCHASESINSTALLMENTSFREQUENCY`: 할부 구매가 이루어지는 빈도 (0과 1 사이의 값, 1은 매우 자주 수행, 0은 자주 수행하지 않음)
# - `CASHADVANCEFREQUENCY`: 현금 서비스 이용 빈도
# - `CASHADVANCETRX`: 현금 서비스 거래 건수
# - `PURCHASES_TRX`: 구매 거래 건수
# - `CREDIT_LIMIT`: 사용자의 신용카드 한도
# - `PAYMENTS`: 사용자가 지불한 총 금액
# - `MINIMUM_PAYMENTS`: 사용자가 지불한 최소 금액
# - `PRCFULLPAYMENT`: 사용자가 전액 결제한 비율
# - `TENURE`: 사용자의 신용카드 서비스 이용 기간 (개월)

# %% [markdown]
# ## 코드잇의 데이터 설명
#
# 위 데이터는 약 9000명의 신용 카드 사용자들의 지난 6개월 동안의 사용 행태를 요약한 것으로, 18개의 행동 변수로 구성되어 있습니다.
#
# 이 미션에서는 신용 카드 회사의 마케팅 담당자라고 상상해 보세요. 고객의 사용 패턴을 분석하여 고객을 몇 개의 그룹으로 세분화하고, 각 그룹에 맞는 마케팅 전략을 수립할 것입니다. 이를 통해 회사의 매출을 증대시키고, 고객 만족도를 높이는 방법을 찾는 것이 목표입니다. 고객을 모델링을 통해 나눌수도 있고, 특정 지표를 기반으로 구분할 수도 있겠죠. 데이터 분석을 통해 어떤 전략이 효과적일지 아이디어를 얻어보세요.
#
# | 컬럼명                           | 설명                                      |
# |---------------------------------|-------------------------------------------|
# | CUST_ID                         | 고객 ID                                   |
# | BALANCE                         | 미상환잔액 (카드 사용 후 아직 결제되지 않은 금액) |
# | BALANCE_FREQUENCY               | 미상환잔액 업데이트 빈도                        |
# | PURCHASES                       | 총 구매 금액                               |
# | ONEOFF_PURCHASES                | 일시불 구매 금액                            |
# | INSTALLMENTS_PURCHASES          | 할부 구매 금액                              |
# | CASH_ADVANCE                    | 현금 서비스 금액                            |
# | PURCHASES_FREQUENCY             | 구매 빈도                                  |
# | ONEOFF_PURCHASES_FREQUENCY      | 일시불 구매 빈도                            |
# | PURCHASES_INSTALLMENTS_FREQUENCY| 할부 구매 빈도                              |
# | CASH_ADVANCE_FREQUENCY          | 현금 서비스 빈도                            |
# | CASH_ADVANCE_TRX                | 현금 서비스 거래 수                          |
# | PURCHASES_TRX                   | 구매 거래 수                                |
# | CREDIT_LIMIT                    | 신용 한도                                  |
# | PAYMENTS                        | 총 결제 금액                               |
# | MINIMUM_PAYMENTS                | 최소 결제 금액                              |
# | PRC_FULL_PAYMENT                | 전액 결제 비율                              |
# | TENURE                          | 계좌 유지 기간                              |

# %% [markdown]
# # 라이브러리 import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

from kneed import KneeLocator

# %%
df = pd.read_csv('./data/credit_card.csv')

# %%
display(df.head(10))
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# ...

# %%
# 작업의 용이성을 위해 컬럼 이름을 소문자로 변환
df.columns = [col.lower() for col in df.columns]

# %%
# 데이터 확인
display(df.head(10))
# Out:
#   cust_id      balance  balance_frequency  purchases  oneoff_purchases  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    installments_purchases  cash_advance  purchases_frequency  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# ...

# %% [markdown]
# # 데이터 기술 통계량 / 결측치 / 최빈값 확인

# %%
# 기본 통계량 (데이터의 크기, 타입, 결측치, describe 내용 확인) 출력 함수
def basic_information(df):
    print(f'data shape : {df.shape}')
    
    basic_info_df = pd.DataFrame(data=df.dtypes, columns=['dtypes'])
    basic_info_df['missing'] = df.isnull().sum().values
    basic_info_df['missing_rate (%)'] = df.isnull().sum().values / len(df) * 100
    basic_info_df['nunique'] = df.nunique().values

    # describe 통계량 (수치형/범주형 포함)
    desc_df = df.describe(include='all').transpose()

    # 수치형 항목만 해당되는 통계량 추가
    for col in ['mean', 'std', 'min','25%', '50%', '75%', 'max']:
        if col in desc_df.columns:
            basic_info_df[col] = desc_df[col]

    # 최빈값 및 해당 최빈값의 count
    basic_info_df['mode'] = {col: df[col].mode(dropna=True).iloc[0] if not df[col].mode(dropna=True).empty else None for col in df.columns}
    basic_info_df['mode_counts'] = {col: df[col].value_counts().max() if not df[col].value_counts().empty else 0 for col in df.columns}

    return basic_info_df

# %%
display(basic_information(df))
# Out:
# data shape : (8950, 18)
#                                    dtypes  missing  missing_rate (%)  nunique  \
# cust_id                            object        0          0.000000     8950
# balance                           float64        0          0.000000     8871
# balance_frequency                 float64        0          0.000000       43
# purchases                         float64        0          0.000000     6203
# oneoff_purchases                  float64        0          0.000000     4014
# installments_purchases            float64        0          0.000000     4452
# cash_advance                      float64        0          0.000000     4323
# purchases_frequency               float64        0          0.000000       47
# oneoff_purchases_frequency        float64        0          0.000000       47
# purchases_installments_frequency  float64        0          0.000000       47
# cash_advance_frequency            float64        0          0.000000       54
# ...

# %% [markdown]
# 결측치는 다음과 같은 내용을 파악할 수 있었고, 결측치를 처리하는 방안을 다음과 같이 고민하며 밑줄친 내용을 토대로 결측치를 처리하여 진행하였다.
#
# `credit_limit` 결측치 관련
# - 1개의 결측치가 발견
# - 이는 전체 데이터의 0.01%의 비율임을 알 수 있다. 이는 무시해도 무방한 수준의 결측치이다.
# - 이 결측치를 처리하는 방안은 다음과 같이 처리할 수 있다고 판단된다.
#   - nunique값이 205개지만, 데이터의 단위가 100단위로 떨어지는 것을 확인되기에, 평균값이 아닌 최빈값으로 데이터를 채워 데이터의 분포를 유지하는 방안.
#   - <ins>해당 컬럼은 **신용 한도**의 내용을 담고 있고 이는 유저가 설정할 수 있는 데이터이며 이를 쉽게 결측치를 채우는 것은 데이터의 의미를 왜곡 시킬 수 있으므로, 삭제하는 방안.</ins>
#
# `minimum_payments` 결측치 관련
# - 313개의 결측치가 발견
# - 이는 전체 데이터의 3.49%의 비율임을 알 수 있다. 이는 무시하기엔 어느 정도 무시할 수 없는 수준의 결측치로 판단된다.
# - 이 결측치를 처리하는 방안은 다음과 같이 처리할 수 있다고 판단된다.
#   - <ins>nunique값이 8636개의 값을 가지고 있고, 값이 연속적으로 변하고 있는 것으로 확인되며, 데이터의 분포를 유지하기 위해 평균값 혹은 중앙값으로 채우는 방안.</ins>
#   - 해당 컬럼은 **최소 결제 금액**의 내용을 담고 있고, 이는 유저의 거래내역을 살펴봐야 알 수 있는 데이터이기 때문에 이를 쉽게 결측치를 채우는 것은 어려우므로, 삭제하는 방안.

# %% [markdown]
# ## 데이터 결측치 처리

# %%
# 전처리하지 않은 데이터 보존
df_original_v1 = df.copy()

# credit_limit 결측치 처리
# credit_limit 결측치는 dropna를 통해서 데이터 결측치 처리
df = df.dropna(subset='credit_limit')

# minimum_payments 결측치 처리
# minimum_payments 결측치는 중앙값으로 처리하는 방안을 채택
# 이유는 표준편차 확인한 결과 평균보다 표준편차가 큰데 이는 이상치가 존재할 가능성이 매우 크다는 것을 알 수 있다
# 또한 min/max값을 확인한 결과 범위가 매우 큰데 이는 이상치가 무조건 존재한다는 것을 알 수 있음
# 표준편차를 줄이기 위해서는 평균값이 아닌 중앙값으로 대처하는게 가장 이상적
df['minimum_payments'] = df['minimum_payments'].fillna(df['minimum_payments'].median())

# 데이터 확인 및 기술통계량 확인
display(df)
display(basic_information(df))
# Out:
#      cust_id      balance  balance_frequency  purchases  oneoff_purchases  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       installments_purchases  cash_advance  purchases_frequency  \
# ...

# %% [markdown]
# ## 데이터 중복값 처리

# %%
# 데이터 중복값 확인
display(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [cust_id, balance, balance_frequency, purchases, oneoff_purchases, installments_purchases, cash_advance, purchases_frequency, oneoff_purchases_frequency, purchases_installments_frequency, cash_advance_frequency, cash_advance_trx, purchases_trx, credit_limit, payments, minimum_payments, prc_full_payment, tenure]
# Index: []

# %% [markdown]
# 데이터의 중복값이 존재하지 않았다.

# %% [markdown]
# ## 데이터 이상치 처리

# %% [markdown]
# IQR 방식을 통해 각 컬럼의 이상치가 얼마나 존재하는지 확인하고자 하였다.

# %%
# IQR 작업 전 수치형 변수만 택하는 데이터만 따로 수행
numeric_df = df.select_dtypes(['int', 'float'])

# IQR 계산
Q1 = numeric_df.quantile(0.25)
Q3 = numeric_df.quantile(0.75)
IQR = Q3 - Q1

# 각 컬럼별 이상치가 얼마나 존재하는지 확인
total_rows = df.shape[0]
for col in numeric_df.columns:
    lower_bound = Q1[col] - 1.5 * IQR[col]
    upper_bound = Q3[col] + 1.5 * IQR[col]
    outlier_count = df[(df[col] < lower_bound) | (df[col] > upper_bound)].shape[0]
    outlier_ratio = outlier_count / total_rows * 100
    print(f"{col}: {outlier_count} outliers ({outlier_ratio:.2f}%)")
# Out:
# balance: 695 outliers (7.77%)
# balance_frequency: 1492 outliers (16.67%)
# purchases: 808 outliers (9.03%)
# oneoff_purchases: 1013 outliers (11.32%)
# installments_purchases: 867 outliers (9.69%)
# cash_advance: 1030 outliers (11.51%)
# purchases_frequency: 0 outliers (0.00%)
# oneoff_purchases_frequency: 782 outliers (8.74%)
# purchases_installments_frequency: 0 outliers (0.00%)
# cash_advance_frequency: 525 outliers (5.87%)
# cash_advance_trx: 804 outliers (8.98%)
# purchases_trx: 766 outliers (8.56%)
# credit_limit: 248 outliers (2.77%)
# payments: 808 outliers (9.03%)
# minimum_payments: 909 outliers (10.16%)
# prc_full_payment: 1474 outliers (16.47%)
# tenure: 1365 outliers (15.25%)

# %% [markdown]
# - 이상치가 10%를 넘어가는 데이터는 다음과 같다.
#     - `balance_frequency`
#     - `oneoff_purchases`
#     - `cash_advance`
#     - `prc_full_payment`
#     - `tenure`
# - 이상치가 5% ~ 10% 미만인 데이터는 다음과 같다.
#   - `balance`, `purchases`, `installments_purchases`, `payments`, `minimum_payments`
#   - `oneoff_purchses_frequency`, `cash_advance_frequency`
#   - `cash_advance_trx`, `purchase_trx`
# - 이상치가 거의 존재하지 않는 데이터는 다음과 같다.
#   - `credit_limit`
#   - `purchases_frequency`, `purchases_installment_frequency`

# %% [markdown]
# ## 이상치가 10%를 넘어가는 데이터의 전처리 과정

# %% [markdown]
# 현재 데이터에서 이상치 처리를 하기 전 다음과 같은 기준을 두어 데이터 이상치 처리를 진행하였다.
# - 데이터가 0과 1 사이의 데이터를 가지고 있음
#   - 구간화를 통한 라벨 인코딩 (5개의 구간으로 지정)
# - 데이터 극단적인 값을 가지고 있는 데이터
#   - 로그 변환

# %%
# 이상치 처리하기 전의 데이터를 보존
df_original_v2 = df.copy()

# %%
# 자주 쓰일 것 같은 시각화 함수는 따로 커스텀 함수로 지정하여 저장
def create_plt_func(col):
    # 그래프를 그려 데이터의 분포 상태 확인
    fig, axes = plt.subplots(1, 2, figsize=(16, 8))
    ax = axes.flatten()

    # histplot 시각화 및 설정
    sns.histplot(data=df[col], bins=30, kde=True, ax=ax[0])
    ax[0].set_title(f'Histplot ({col})')
    ax[0].set_xlabel(col)
    ax[0].set_ylabel('Count')
    ax[0].grid()

    sns.boxplot(data=df[col], ax=ax[1])
    ax[1].set_title(f'Boxplot ({col})')
    ax[1].set_xlabel(col)
    ax[1].set_ylabel('Count')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 수치형 변수들의 기술 통계량 요약본 확인

# %%
df.select_dtypes(['int', 'float']).describe()
# Out:
#             balance  balance_frequency     purchases  oneoff_purchases  \
# count   8949.000000        8949.000000   8949.000000       8949.000000
# mean    1564.647593           0.877350   1003.316936        592.503572
# std     2081.584016           0.236798   2136.727848       1659.968851
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.365782           0.888889     39.800000          0.000000
# 50%      873.680279           1.000000    361.490000         38.000000
# 75%     2054.372848           1.000000   1110.170000        577.830000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        installments_purchases  cash_advance  purchases_frequency  \
# count             8949.000000   8949.000000          8949.000000
# mean               411.113579    978.959616             0.490405
# std                904.378205   2097.264344             0.401360
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# 각 기술통계량을 확인한 결과 다음과 같은 내용을 확인할 수 있었다.
#
# 극단적인 값을 가지는 데이터 (로그변환 후 이상치 제거)
# - `balance`
# - `purchases`
# - `oneoff_purchases`
# - `installments_purchases`
# - `cash_advance`
# - `cash_advance_trx`
# - `purchases_trx`
# - `credit_limit`
# - `payments`
# - `minimum_payments`
#
# 데이터가 어느 범주 안에 연속적으로 분포해 있는 데이터 (구간화를 통한 라벨 인코딩 또는 그대로 사용)
# - `purchases_frequency`
# - `oneoff_purchases_frequency`
# - `purchases_installments_frequency`
# - `cash_advance_frequemcy`
# - `prc_full_payment`
#
# 데이터는 수치로 표현되어 있지만 순서형 데이터로 확인되는 데이터 (이상치 제거가 불필요)
# - `tenure`

# %% [markdown]
# ### 극단적인 값을 보이는 데이터 이상치 제거

# %%
# 극단적인 값을 보이는 컬럼들을 리스트화
unlimited_cols = ['balance', 'purchases', 'oneoff_purchases',
                  'installments_purchases', 'cash_advance', 'cash_advance_trx',
                  'purchases_trx', 'credit_limit', 'payments', 'minimum_payments']

# 각각의 데이터의 분포 확인
for col in unlimited_cols:
    create_plt_func(col)

# %%
# 각각 로그 변환을 취해준 뒤 데이터 분포 확인
for col in unlimited_cols:
    df[col] = df[col].apply(lambda x: np.log1p(x) if x > 1 else x) # 로그 후 중간값 왜곡 방지를 위한 if문 필터링

# 다시 데이터의 분포 확인
for col in unlimited_cols:
    create_plt_func(col)

# %% [markdown]
# 극단적인 값들만 가지는 데이터를 로그 변환을 하였고 이상치 처리를 다시 확인한 결과 다음과 같다.

# %%
# IQR 작업 전 수치형 변수만 택하는 데이터만 따로 수행
numeric_df = df.select_dtypes(['int', 'float'])

# IQR 계산
Q1 = numeric_df.quantile(0.25)
Q3 = numeric_df.quantile(0.75)
IQR = Q3 - Q1

# 각 컬럼별 이상치가 얼마나 존재하는지 확인
total_rows = df.shape[0]
for col in numeric_df.columns:
    lower_bound = Q1[col] - 1.5 * IQR[col]
    upper_bound = Q3[col] + 1.5 * IQR[col]
    outlier_count = df[(df[col] < lower_bound) | (df[col] > upper_bound)].shape[0]
    outlier_ratio = outlier_count / total_rows * 100
    print(f"{col}: {outlier_count} outliers ({outlier_ratio:.2f}%)")
# Out:
# balance: 123 outliers (1.37%)
# balance_frequency: 1492 outliers (16.67%)
# purchases: 0 outliers (0.00%)
# oneoff_purchases: 0 outliers (0.00%)
# installments_purchases: 0 outliers (0.00%)
# cash_advance: 0 outliers (0.00%)
# purchases_frequency: 0 outliers (0.00%)
# oneoff_purchases_frequency: 782 outliers (8.74%)
# purchases_installments_frequency: 0 outliers (0.00%)
# cash_advance_frequency: 525 outliers (5.87%)
# cash_advance_trx: 15 outliers (0.17%)
# purchases_trx: 5 outliers (0.06%)
# credit_limit: 6 outliers (0.07%)
# payments: 317 outliers (3.54%)
# minimum_payments: 168 outliers (1.88%)
# prc_full_payment: 1474 outliers (16.47%)
# tenure: 1365 outliers (15.25%)

# %%
# 데이터의 기술 통계량 함수 다시 출력
display(basic_information(df))
# Out:
# data shape : (8949, 18)
#                                    dtypes  missing  missing_rate (%)  nunique  \
# cust_id                            object        0               0.0     8949
# balance                           float64        0               0.0     8870
# balance_frequency                 float64        0               0.0       43
# purchases                         float64        0               0.0     6203
# oneoff_purchases                  float64        0               0.0     4014
# installments_purchases            float64        0               0.0     4452
# cash_advance                      float64        0               0.0     4322
# purchases_frequency               float64        0               0.0       47
# oneoff_purchases_frequency        float64        0               0.0       47
# purchases_installments_frequency  float64        0               0.0       47
# cash_advance_frequency            float64        0               0.0       54
# ...

# %% [markdown]
# 극단적인 값을 로그 변환후 이상치 처리 결과 다음과 같다.
#
# | **항목**                                   | **개선 내용**               | **의미**                                                       |
# |-------------------------------------------|-----------------------------|----------------------------------------------------------------|
# | `balance`                                 | 7.77% → 1.37%               | 분산이 줄고 중심값에 더 가까워짐                              |
# | `purchases`, `oneoff_purchases`, `installments_purchases`, `cash_advance` | 모두 0% 이상치             | 극단적 소비/현금 사용값의 왜곡 제거 성공                     |
# | `payments`                                 | 9.03% → 3.54%               | 안정적인 결제 패턴 반영 가능                                  |
# | `minimum_payments`                         | 10.16% → 1.88%              | 일부 매우 높은 금액들의 비정상적 영향 제거                    |
# | `cash_advance_trx`, `purchases_trx`        | 8.98%, 8.56% → 0.17%, 0.06% | 트랜잭션 수 기준의 이상 행동 탐지 개선                        |
# | `credit_limit`                             | 2.77% → 0.07%               | 클러스터링 시 신용한도 극단값이 중심에 미치는 영향 감소      |

# %%
# 전처리한 데이터를 저장
df_original_v3 = df.copy()

# %% [markdown]
# # 비지도 클러스터링

# %%
# 데이터 스케일링
# dust_id와 tenure는 스케일링에서 제외 (범주형 변수이기 떄문)
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df.drop(labels=['cust_id', 'tenure'], axis=1))

# %% [markdown]
# ## Elbow Method

# %% [markdown]
# 먼저 Elbow Method를 이용하여 현재 데이터에서 얻을 수 있는 최적의 군집 k 갯수를 구하였다. 또한 kneed 라이브러리를 통해 우리가 직접 그래프를 보고 판단하지 않고 라이브러리에서 최적의 군집을 설정해주는 도구를 통해 k를 찾아내는 과정을 거쳤다.

# %%
# Elbow Method를 통한 최적의 군집 갯수 찾기
inertia_list = []

# k의 군집 갯수 지정하기
k_range = range(1, 16)

for k in range(1, 16):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_df)
    inertia = kmeans.inertia_
    inertia_list.append(inertia)

kl = KneeLocator(
    x=range(1, 16),
    y=inertia_list,
    curve='convex',
    direction='decreasing'
)

# 계산을 용이하게 하기 위한 numpy 배열 변환
inertia_arr = np.array(inertia_list)    

# Elbow Method 시각화
plt.figure(figsize=(15, 10))
sns.lineplot(x=range(1, 16), y=inertia_list, marker='o')
plt.axvline(x=kl.knee, color='red', linestyle='--', label=f"Optimal k = {kl.knee}")
plt.xlabel("Number of clusters", fontsize=16)
plt.ylabel("Inertia", fontsize=16)
plt.title("Elbow Method for Optimal k", fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# Elbow Method를 통해 최적의 군집 개수는 6개로 정해졌으므로, 6개의 클러스터링을 통해 군집파악을 해보고자 하였다.

# %% [markdown]
# ## PCA

# %% [markdown]
# PCA를 통한 차원 축소를 통해 데이터를 저차원으로 줄여 고차원의 데이터를 시각화하기에 용이하도록 하고자 작업을 진행하였다.
#
# 하지만 차원 축소를 진행하게 될 경우, 데이터의 정보가 최대한 보존된다고 하여도 없어지는 정보들이 있기 때문에, 차원 축소를 통해 데이터의 차원을 축소하기 데이터의 95%를 설명하는 PCA의 개수를 파악하고자 하였다.

# %%
# PCA 전체 주성분 계산
pca = PCA()
pca.fit(scaled_df)

# 누적 분산 계산
cumulative_variance = pca.explained_variance_ratio_.cumsum()

# 시각화
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='-')
plt.axhline(y=0.95, color='r', linestyle='--', label='95% Variance Threshold')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance vs. Number of Components')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 하지만 9차원의 데이터를 시각화 하기에는 불가능한 차원이기에 데이터를 2D로 시작화 하기 위해 2차원으로 축소하였다.

# %%
pca = PCA(n_components=2)
pca_df = pd.DataFrame(pca.fit_transform(scaled_df), columns=['PCA1', 'PCA2'])

display(pca_df)
# Out:
#           PCA1      PCA2
# 0    -0.297531 -2.743008
# 1    -3.473033  0.944726
# 2     1.520680  1.308969
# 3    -1.280692 -1.105097
# 4    -1.092661 -1.365718
# ...        ...       ...
# 8944  1.992941 -2.399088
# 8945  1.548553 -1.737671
# 8946  1.261550 -2.839641
# 8947 -2.477621 -3.546921
# 8948  0.164772 -0.318502
#
# [8949 rows x 2 columns]

# %% [markdown]
# ## K-Means

# %% [markdown]
# 최적의 군집은 6개인 것으로 확인 되었으며 클러스터의 값을 6개로 설정하여 K-Means를 진행하였다.

# %%
# K-Means 초기화
kmeans = KMeans(n_clusters=5, random_state=42)

# 이상치 처리를 하지 않은 데이터를 가져와 cluster한 데이터를 붙임
origin_df = df_original_v2.copy()

# k-means를 통한 클러스터링 데이터 추가
# 시각화를 위해 PCA 데이터프레임에도 데이터 추가
origin_df['cluster'] = kmeans.fit_predict(scaled_df)
pca_df['cluster'] = kmeans.fit_predict(scaled_df)

# 데이터 확인
display(origin_df)
# Out:
#      cust_id      balance  balance_frequency  purchases  oneoff_purchases  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       installments_purchases  cash_advance  purchases_frequency  \
# ...

# %%
# 클러스터링 결과 시각화 (PCA로 축소된 2D 데이터)
plt.figure(figsize=(10, 6))
sns.scatterplot(data=pca_df, x='PCA1', y='PCA2', hue='cluster', palette='viridis', s=20)
plt.axhline(y=0, color='gray', linestyle='--')
plt.axvline(x=0, color='gray', linestyle='--')
plt.title('PCA + KMeans Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Cluster')
plt.show()

# 5. PCA의 변동성 설명 (주성분별 설명된 분산 비율)
print(f"Explained Variance Ratio: {pca.explained_variance_ratio_}")
print(f"Total Explained Variance: {sum(pca.explained_variance_ratio_)}")
# Out:
# Explained Variance Ratio: [0.36034049 0.23130535]
# Total Explained Variance: 0.5916458446991997

# %%
# 각 클러스터별 groupby하여 평균적인 분포 확인
origin_groupby_kmeans = origin_df.select_dtypes(['int', 'float']).groupby('cluster').mean().reset_index()

# 데이터 확인
display(origin_groupby_kmeans)

# 실루엣 점수 확인
cluster_labels = kmeans.fit_predict(scaled_df)
score = silhouette_score(scaled_df, cluster_labels)
print(f'Silhouette Score : {score:.4f}')
# Out:
#    cluster      balance  balance_frequency    purchases  oneoff_purchases  \
# 0        0  2284.530561           0.935024    24.475755         21.938115
# 1        1  1521.569934           0.973852  2884.963702       1984.367861
# 2        2  3268.704979           0.975131  1336.620455        775.540035
# 3        3   435.066033           0.904085   645.280773         37.972456
# 4        4   288.819389           0.550486   344.999353        280.061491
#
#    installments_purchases  cash_advance  purchases_frequency  \
# 0                2.590129   2021.158702             0.022914
# 1              900.673647     54.721221             0.842405
# 2              561.305059   2609.684356             0.669059
# 3              608.259608     28.070449             0.814487
# 4               65.169680    127.118743             0.220105
#
#    oneoff_purchases_frequency  purchases_installments_frequency  \
# 0                    0.017005                          0.005056
# ...

# %% [markdown]
# ## DBSCAN

# %% [markdown]
# DBSCAN은 군집개수를 설정하지 않아도 밀도 기반으로 자동으로 클러스터를 계산해준다. DBSCAN에 들어갈 파라미터는 다음과 같다.
#
# - eps : 한 포인트 주변을 이웃으로 간주할 반경
# - min_samples : 최소 이웃 수 (핵심 포인트가 되기 위한 조건)
# - metric : 거리 계산 방식 (기본은 유클리드 거리)
#
# metric는 유클리드 거리 방식으로 계산할 것이기 떄문에 따로 지정을 하지 않았다.

# %%
# DBSCAN의 평가 변수 초기화
best_score = -1
best_params = (None, None)

# 결과를 저장할 리스트 변수 초기화
results = []

#DBSCAN의 그리드 서치를 통해 최적의 파라미터값 구하기
for eps in np.arange(0.1, 2.1, 0.1):
    for min_sample in range(1, 5):
        dbscan = DBSCAN(eps=eps, min_samples=min_sample)
        labels = dbscan.fit_predict(scaled_df)
        
        # 노이즈 제외
        mask = labels != -1
        n_clusters = len(set(labels[mask]))
        
        if n_clusters >= 2:
            score = silhouette_score(scaled_df[mask], labels[mask])
            results.append((eps, min_sample, score))
            
            if score > best_score:
                best_score = score
                best_params = (eps, min_sample)

print(f"\nBest Silhouette Score: {best_score:.4f} with eps={best_params[0]}, min_samples={best_params[1]}")
# Out:
# Best Silhouette Score: 0.9825 with eps=0.1, min_samples=3

# %%
# 그리드 서치를 통한 파라미터 조합으로 클러스터링 진행
dbscan = DBSCAN(eps=0.1, min_samples=3)

# 클러스터된 데이터열 추가
origin_df['cluster'] = dbscan.fit_predict(scaled_df)
pca_df['cluster'] = dbscan.fit_predict(scaled_df)

# dbscan 클러스터를 groupby하여 각 클러스터별 평균적인 분포 확인
origin_groupby_dbscan = origin_df.select_dtypes(['int', 'float']).groupby('cluster').mean()

# 데이터 확인
display(origin_groupby_dbscan)
# Out:
#              balance  balance_frequency   purchases  oneoff_purchases  \
# cluster
# -1       1564.920626           0.877254  1003.93764        592.967398
#  0       1375.392302           1.000000     0.00000          0.000000
#  1       1003.166342           1.000000   490.96000          0.000000
#
#          installments_purchases  cash_advance  purchases_frequency  \
# cluster
# -1                   411.270693    979.693303             0.490454
#  0                     0.000000     73.020924             0.000000
#  1                   490.960000      0.000000             1.000000
#
#          oneoff_purchases_frequency  purchases_installments_frequency  \
# cluster
# -1                         0.202639                          0.364428
#  0                         0.000000                          0.000000
#  1                         0.000000                          1.000000
#
#          cash_advance_frequency  cash_advance_trx  purchases_trx  \
# cluster
# ...

# %%
# 클러스터링 결과 시각화 (PCA로 축소된 2D 데이터)
plt.figure(figsize=(10, 6))
sns.scatterplot(data=pca_df, x='PCA1', y='PCA2', hue='cluster', palette='viridis', s=20)
plt.axhline(y=0, color='gray', linestyle='--')
plt.axvline(x=0, color='gray', linestyle='--')
plt.title('PCA + DBSCAN Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Cluster')
plt.show()

# 5. PCA의 변동성 설명 (주성분별 설명된 분산 비율)
print(f"Explained Variance Ratio: {pca.explained_variance_ratio_}")
print(f"Total Explained Variance: {sum(pca.explained_variance_ratio_)}")
# Out:
# Explained Variance Ratio: [0.36034049 0.23130535]
# Total Explained Variance: 0.5916458446991997

# %% [markdown]
# 실루엣 점수는 높으나, 원하고자 하는 클러스터는 아니었음.

# %% [markdown]
# ## GMM

# %% [markdown]
# GMM은 확률 기반 클러스터링 기법으로, K-Means보다 더 유연하고 통계적인 접근을 제공한다.

# %%
gmm = GaussianMixture(n_components=5, random_state=42)

# GMM 클러스터링 데이터 입력
origin_df['cluster'] = gmm.fit_predict(scaled_df)
pca_df['cluster'] = gmm.fit_predict(scaled_df)

# 소속 확률 구하기
probs = gmm.predict_proba(scaled_df) # 각 샘플이 클러스터에 속할 확률

# %%
# 클러스터링 결과 시각화 (PCA로 축소된 2D 데이터)
plt.figure(figsize=(10, 6))
sns.scatterplot(data=pca_df, x='PCA1', y='PCA2', hue='cluster', palette='viridis', s=20)
plt.axhline(y=0, color='gray', linestyle='--')
plt.axvline(x=0, color='gray', linestyle='--')
plt.title('PCA + GMM Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Cluster')
plt.show()

# %%
# gmm 클러스터를 groupby하여 각 클러스터별 평균적인 분포 확인
origin_groupby_dbscan = origin_df.select_dtypes(['int', 'float']).groupby('cluster').mean()

# 데이터 확인
display(origin_groupby_dbscan)

# 실루엣 점수 확인
cluster_labels = kmeans.fit_predict(scaled_df)
score = silhouette_score(scaled_df, cluster_labels)
print(f'Silhouette Score : {score:.4f}')
# Out:
#              balance  balance_frequency    purchases  oneoff_purchases  \
# cluster
# 0        1915.392129           0.863639   261.657613        261.657613
# 1        1151.163717           0.926222  2338.786606       1521.718014
# 2        3158.249439           1.000000  1457.123732        749.525403
# 3         397.795977           0.788326   535.374818          0.000000
# 4        1213.065775           0.803575  1525.830090        969.514719
#
#          installments_purchases  cash_advance  purchases_frequency  \
# cluster
# 0                      0.000000   1572.873954             0.094812
# 1                    817.162431      0.000000             0.804052
# 2                    708.209861   2058.695592             0.750483
# 3                    535.374818      0.000000             0.705972
# 4                    560.338697   1845.469426             0.665596
#
#          oneoff_purchases_frequency  purchases_installments_frequency  \
# cluster
# ...

# %% [markdown]
# # 분석 결론

# %% [markdown]
# 각 클러스터링에 대한 분석 결론은 다음과 같다.
#
# - K-Means에 대한 클러스터는 타원형의 데이터를 잘 잡아내지 못했다.
# - DBSCAN에 대한 클러스터는 분명 군집화가 잘 이루어진 것 같지만, 분리를 하지 못한 군집화를 나타내었다.
# - Gaussian Mixture Model의 클러스터는 K-Means 보다 비교정 타원형의 데이터를 잘 잡아내어 K-Means 보다 좀 더 보완된 클러스터의 성격을 가지고 있다.
#
# 이를 통해 Gaussian Mixture Model의 클러스터를 통해 데이터를 분석하는 것이 용이하다고 판단하였다.
#
# 또한 원본 데이터를 2차원으로 축소한 뒤 각각의 PCA가 어떤 변수를 설명하는지에 대한 내용은 다음과 같다.

# %%
# PCA 구성 요소 확인
pca_components = pd.DataFrame(
    pca.components_,  # PCA 구성 요소
    columns=df.drop(labels=['cust_id', 'tenure'], axis=1).columns,  # 원래 feature 이름들
    index=['PCA1', 'PCA2']  # 주성분 이름
)

display(pca_components.T.sort_values(by='PCA1', ascending=False))  # PCA1에 영향을 많이 준 변수 순 정렬
display(pca_components.T.sort_values(by='PCA2', ascending=False))  # PCA2에 영향을 많이 준 변수 순 정렬
# Out:
#                                       PCA1      PCA2
# purchases_trx                     0.376565  0.171546
# purchases_frequency               0.366501  0.126837
# purchases                         0.364183  0.128560
# installments_purchases            0.326220  0.079045
# purchases_installments_frequency  0.312491  0.078081
# oneoff_purchases_frequency        0.218672  0.222145
# oneoff_purchases                  0.208667  0.222508
# prc_full_payment                  0.178927 -0.117452
# payments                          0.051750  0.315424
# credit_limit                      0.045698  0.248914
# balance_frequency                 0.017847  0.331516
# minimum_payments                 -0.103945  0.365028
# balance                          -0.123621  0.437049
# cash_advance_frequency           -0.249274  0.272667
# cash_advance_trx                 -0.284918  0.279571
# cash_advance                     -0.298856  0.254639
#                                       PCA1      PCA2
# ...

# %% [markdown]
# PCA1은 구매 활동과 관련된 패턴을 설명하는 것으로 나타났다.
#
# PCA1를 설명하는 주요 변수들
#
# - `purchases_trx` (0.376565)
# - `purchases_frequency` (0.366501)
# - `purchases` (0.364183)
# - `installments_purchases` (0.326220)
# - `purchases_installments_frequency` (0.312491)
#
# PCA2는 금융 상태와 관련된 패턴을 설명하는 것으로 나타났다.
#
# PCA2를 설명하는 주요 변수들
#
# - `balance` (0.437049) :
# - `minimum_payments` (0.365028) :
# - `balance_frequency` (0.331516) :
# - `payments` (0.315424) :
# - `cash_advance_frequency` (0.272667) :
# - `cash_advance` (0.254639) :

# %% [markdown]
# ## 각 군집별 솔루션 내용
#
# ### Cluster0 Solution
# PCA1 값이 낮고 PCA2 값이 중간 이하의 값으로 보인다. 이는 구매활동이 적고, 금용 상태는 평균 이하일 수도 있는 고객 그룹.
# > 구매활동을 촉진하기 위한 근본적은 동기 부여 전략 필요.
# > - 개인화된 상품 추천
# > - 특별 할인 제공
# > - 금융 교육 프로그램 안내
# ### Cluster1 Solution
# PCA1 값은 중간 정도이고 PCA2 값은 높은 경향을 보인다. 이는 구매호라동을 보통 수준이지만, 금융 상태가 비교적 안정적인 고객 그룹.
# > 안정적인 금융 상태를 바탕으로 구매 잠재력을 높일 수 있도록 유도.
# > - 관심있을 만한 상품 추천
# > - 이벤트 참여 유도
# > - 장바구니 상품 알림
# ### Cluster2 Solution
# PCA1 값은 높고 PCA2 값은 중간 이하인 경향을 보인다. 이는 구매활동이 활발하지만, 금융 상태는 평균 이하일 수 있는 고객 그룹.
# > 구매 의향은 높지만 금융 상태가 불안정할 수 있음.
# > - 할부 혜택 강화
# > - 결제 편의성 증대
# ### Cluster3 Solution
# PCA1 값이 높고 PCA2 값도 높은 경향을 보인다. 이는 구매활동이 활발하고, 금융 상태도 안정적일 수 있는 고객 그룹.
# > 회사와의 관계를 강화하는 추개 구매를 유도
# > - 프리미엄 상품/서비스 제안
# > - 충성도 프로그램 강화
# > - 맞춤형 VIP 혜택
# ### Cluster4 Solution
# 그래프 전체에 걸쳐 비교적 넓게 분포함. 이는 구매 활동과 금융 상태 모두 중간 수준의 고객 그룹일 수 있지만, 다른 그룹을 포함할 수 있음.
# > 다양한 특성을 가질 수 있으므로 세분화된 분석을 통해 더 작은 그룹으로 나누어 추가적인 데이터 분석 필요.
